# %% [markdown]
# # PPOL564 | Lab 2
#
# Complete the following questions independently and then discuss the results as a class.

# %% [markdown]
# ## Practice Question 1
#
# Create two string objects with the following inputs:
#
# 1. "georgetown university was founded in 1789"
# 2. "UNDERGRADUATE STUDENTS USUALLY BEGIN TO ARRIVE TOWARD THE END OF AUGUST"
#
# Do the following in Python.
#
# - Convert "georgetown university" to title case.
# - Add a period to both sentences.
# - Convert object 2 to normal case. Make sure the start of the sentence and the month are capitalized.
# - Combine the two objects into one string objects, leaving a space between the two sentences.

# %% [markdown]
# ## Practice Question 2
#
# Below is (i) a list of names of students in public policy class A and (ii) a list of students in public policy class B.
#
# - How many students are in both classes?
# - How many students are in class A but not in class B?
# - How many students are in class B but not in class A?

# %%
class_A = [
    'Julie Mao',
    'Sean Gailmard',
    'Ricky Thorson',
    'Susan Scott',
    'Candice Free',
    'Adam Long',
    'Ralph Godes',
    'Marissa Peters',
    'Eddie Wu'
]

class_B = [
    'Henry Erickson',
    'Ricky Thorson',
    'Luvy Zhang',
    'Marissa Peters',
    'Moris Moon',
    'Mara Tabilisi',
    'Julie Mao',
    'Caitlin Car'
]

# %% [markdown]
# ## Practice Question 3
#
# Store the following data into a data object
#
# - Jack bought 4 lemons, 3 carrots, 1 can of peas, and 2 steaks at the store.
# - Susan bought 5 cuts of salmon, 1 bushel of asparagus, and 2 pints of ice cream
# - Eddie bought 1 case of beer, 2 bags of chips, and 1 jar of salsa
#
# After creating the object,
#
# 1. Look up and print everything Eddie bought at the store.
# 2. Add a case of beer to Jack's list.
# 3. Remove a pint of ice cream from Susan's list.

# %% [markdown]
# ## Practice Question 4
#
# The following code loads in a nested list, which contains data on the average country GDP per capita and life expectancy for 142 countries tracked by the [Gapminder data](https://www.gapminder.org/data/).
#
# Please do the following:
#
# - Rearrange the list so that each entry is in alphabetical order by country name and store in a new object.
# - Double check that the original object has not changed.

# %%
import csv
with open("gapminder.csv") as gap_file:
    csv_file = csv.reader(gap_file, delimiter=',')
    gap_data = [row for row in csv_file]
gap_data
# Out:
# [['country', 'lifeExp', 'gdpPercap'],
#  ['Guinea-Bissau', '39.21', '652.157'],
#  ['Bolivia', '52.505', '2961.229'],
#  ['Austria', '73.103', '20411.916'],
#  ['Malawi', '43.352', '575.447'],
#  ['Finland', '72.992', '17473.723'],
#  ['Korea, Dem. Rep.', '63.607', '2591.853'],
#  ['Malaysia', '64.28', '5406.038'],
#  ['Hungary', '69.393', '10888.176'],
#  ['Congo, Rep.', '52.502', '3312.788'],
#  ['Morocco', '57.609', '2447.909'],
#  ['Germany', '73.444', '20556.684'],
#  ['Ecuador', '62.817', '5733.625'],
#  ['Kuwait', '68.922', '65332.91'],
#  ['New Zealand', '73.989', '17262.623'],
#  ['Mauritania', '52.302', '1356.671'],
#  ['Uganda', '47.619', '810.384'],
#  ['Equatorial Guinea', '42.96', '2469.167'],
#  ['Croatia', '70.056', '9331.712'],
#  ['Indonesia', '54.336', '1741.365'],
#  ['Canada', '74.903', '22410.746'],
#  ['Comoros', '52.382', '1314.38'],
#  ['Montenegro', '70.299', '7208.065'],
#  ['Slovenia', '71.601', '14074.582'],
# ...

# %% [markdown]
# ## Bonus Advanced Question:
#
# Keeping with the Gapminder data loaded in for Q4,
#
# - Rearrange the list so that each entry is in descending order by average life expectancy in a new object.
